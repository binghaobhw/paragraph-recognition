# %%
import experiment as e
import method as m

# %%
m.configure(e.method_config)

# %%
result = e.k_fold_cross(5, 355)

# %%
import json
print json.dumps(result, indent=4)
# Out:
# {
#     "fan_yang": {
#         "0": {
#             "new": {
#                 "new": 59,
#                 "F1": 0.6178010471204188,
#                 "R": 0.6145833333333334,
#                 "P": 0.6210526315789474,
#                 "follow": 36
#             },
#             "all": {
#                 "false": 73,
#                 "true": 94,
#                 "P": 0.562874251497006
#             },
#             "follow": {
#                 "new": 37,
#                 "F1": 0.4895104895104895,
#                 "R": 0.49295774647887325,
#                 "P": 0.4861111111111111,
#                 "follow": 35
#             }
#         },
#         "1": {
#             "new": {
#                 "new": 63,
#                 "F1": 0.6494845360824744,
#                 "R": 0.65625,
#                 "P": 0.6428571428571429,
#                 "follow": 35
#             },
#             "all": {
#                 "false": 68,
#                 "true": 99,
# ...

# %%
for i in result:
    print i, json.dumps(result[i]['average'], indent=4)
# Out:
# fan_yang {
#     "new": {
#         "P": 0.6804237433099043,
#         "R": 0.544778669043375,
#         "F1": 0.597671005587534
#     },
#     "all": {
#         "P": 0.5849632534537015
#     },
#     "follow": {
#         "P": 0.5078864769785486,
#         "R": 0.6366197183098592,
#         "F1": 0.5602783613232948
#     }
# }
# my_method {
#     "new": {
#         "P": 0.8239187169419727,
#         "R": 0.7105020796197267,
#         "F1": 0.7620422675205492
#     },
#     "all": {
#         "P": 0.744512420182186
#     },
#     "follow": {
#         "P": 0.6681678645771966,
#         "R": 0.7915492957746479,
#         "F1": 0.7236741124903942
#     }
# }
# de_boni {
#     "new": {
#         "P": 0.5924555230736059,
#         "R": 0.9956439393939395,
#         "F1": 0.7428043440950267
#     },
#     "all": {
#         "P": 0.6037122024707842
#     },
#     "follow": {
#         "P": 0.9416666666666667,
#         "R": 0.07323943661971831,
#         "F1": 0.13525256178420736
#     }
# ...
