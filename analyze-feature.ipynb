# %%
import experiment as e
import method as m
import json

# %%
m.configure(e.method_config)

# %%
af = e.analyze_feature(5, 355, 'my_method')

# %%
for i in af:
    print i, json.dumps(af[i]['average'], indent=4)
# Out:
# origin {
#     "new": {
#         "P": 0.8239187169419727,
#         "R": 0.7105020796197267,
#         "F1": 0.7620422675205492
#     },
#     "all": {
#         "P": 0.744512420182186
#     },
#     "follow": {
#         "P": 0.6681678645771966,
#         "R": 0.7915492957746479,
#         "F1": 0.7236741124903942
#     }
# }
# same_named_entity {
#     "new": {
#         "P": 0.8239187169419727,
#         "R": 0.7105020796197267,
#         "F1": 0.7620422675205492
#     },
#     "all": {
#         "P": 0.744512420182186
#     },
#     "follow": {
#         "P": 0.6681678645771966,
#         "R": 0.7915492957746479,
#         "F1": 0.7236741124903942
#     }
# }
# noun {
#     "new": {
#         "P": 0.8113678279796412,
#         "R": 0.6259469696969696,
#         "F1": 0.7054209575428994
#     },
#     "all": {
#         "P": 0.7016133493599945
#     },
#     "follow": {
#         "P": 0.6152501485442661,
#         "R": 0.8028169014084506,
#         "F1": 0.6959626852559954
# ...
